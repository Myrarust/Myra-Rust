# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read in the data
df = pd.read_excel("total_miles_by_year.xls")
df.head()
# Out:
#   Country Name Country Code                     Indicator Name      1985  \
# 0        Aruba          ABW  Air transport, passengers carried       NaN
# 1  Afghanistan          AFG  Air transport, passengers carried  225500.0
# 2       Angola          AGO  Air transport, passengers carried  894200.0
# 3      Albania          ALB  Air transport, passengers carried       NaN
# 4      Andorra          AND  Air transport, passengers carried       NaN
#
#        1986      1987      1988      1989      1990      1991  ...      2005  \
# 0       NaN       NaN       NaN       NaN       NaN       NaN  ...       NaN
# 1  184400.0  217900.0  201000.0  220000.0  241400.0  212300.0  ...       NaN
# 2  727000.0  746000.0  750000.0  509800.0  451500.0  456000.0  ...  239795.0
# 3       NaN       NaN       NaN       NaN       NaN       NaN  ...  195702.0
# 4       NaN       NaN       NaN       NaN       NaN       NaN  ...       NaN
#
# ...

# %%
# Don't need the first three columns for my viz, drop them. 
df.drop(columns=['Country Code', "Indicator Name"], inplace=True)

# %%
df
# Out:
#      Country Name       1985       1986       1987       1988       1989  \
# 0           Aruba        NaN        NaN        NaN        NaN        NaN
# 1     Afghanistan   225500.0   184400.0   217900.0   201000.0   220000.0
# 2          Angola   894200.0   727000.0   746000.0   750000.0   509800.0
# 3         Albania        NaN        NaN        NaN        NaN        NaN
# 4         Andorra        NaN        NaN        NaN        NaN        NaN
# ..            ...        ...        ...        ...        ...        ...
# 259        Kosovo        NaN        NaN        NaN        NaN        NaN
# 260   Yemen, Rep.   426200.0   589700.0   575500.0   635500.0   667900.0
# 261  South Africa  4337300.0  3825000.0  4386900.0  5125900.0  5641500.0
# 262        Zambia   253900.0   237700.0   257900.0   303500.0   365300.0
# 263      Zimbabwe   453100.0   451500.0   459900.0   525100.0   583400.0
#
#           1990       1991       1992       1993  ...        2005        2006  \
# ...

# %%
# I see a lot of NaNs in the miles columns. Replace those with a value of 0.
df.fillna(0, inplace=True)

# %%
# I want year to be a column, so I'm going to transpose the dataframe and reset the index.
df = df.set_index('Country Name').T.rename_axis('Year')
df.reset_index(inplace=True)
df
# Out:
# Country Name  Year  Aruba   Afghanistan     Angola        Albania  Andorra  \
# 0             1985    0.0  2.255000e+05   894200.0       0.000000      0.0
# 1             1986    0.0  1.844000e+05   727000.0       0.000000      0.0
# 2             1987    0.0  2.179000e+05   746000.0       0.000000      0.0
# 3             1988    0.0  2.010000e+05   750000.0       0.000000      0.0
# 4             1989    0.0  2.200000e+05   509800.0       0.000000      0.0
# 5             1990    0.0  2.414000e+05   451500.0       0.000000      0.0
# 6             1991    0.0  2.123000e+05   456000.0       0.000000      0.0
# 7             1992    0.0  2.123000e+05   440000.0       0.000000      0.0
# 8             1993    0.0  1.970000e+05   333500.0       0.000000      0.0
# 9             1994    0.0  2.384000e+05   519000.0    9100.000000      0.0
# 10            1995    0.0  2.504000e+05   552500.0   13000.000000      0.0
# ...

# %%
# Sweet! I just realized there is a column for world, which is what I need, so I'm going to subset year and world columns. 
world_miles = df[['Year', 'World']]
world_miles
# Out:
# Country Name  Year         World
# 0             1985  7.831981e+08
# 1             1986  8.425943e+08
# 2             1987  9.048381e+08
# 3             1988  9.538960e+08
# 4             1989  9.832088e+08
# 5             1990  1.024977e+09
# 6             1991  1.133228e+09
# 7             1992  1.145437e+09
# 8             1993  1.142265e+09
# 9             1994  1.233233e+09
# 10            1995  1.302892e+09
# 11            1996  1.390964e+09
# 12            1997  1.455104e+09
# 13            1998  1.466962e+09
# 14            1999  1.562256e+09
# 15            2000  1.674065e+09
# 16            2001  1.655230e+09
# 17            2002  1.627405e+09
# 18            2003  1.665309e+09
# 19            2004  1.888695e+09
# 20            2005  1.969591e+09
# 21            2006  2.072414e+09
# 22            2007  2.209136e+09
# 23            2008  2.208219e+09
# 24            2009  2.249729e+09
# 25            2010  2.628261e+09
# 26            2011  2.786954e+09
# ...

# %%
# Write to csv to use in Tableau
world_miles.to_csv('world_miles.csv', index=False)

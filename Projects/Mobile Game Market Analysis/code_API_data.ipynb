# %%
# Import necessary libraries
import urllib.request, urllib.parse, urllib.error
import requests
import json

# %%
# Load the secret API key
with open('42matters.json') as f:
    keys = json.load(f)
    access_token = keys['access_token']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-62748657c2e7> in <module>
#       1 # Load the secret API key
# ----> 2 with open('42matters.json') as f:
#       3     keys = json.load(f)
#       4     access_token = keys['access_token']
#
# FileNotFoundError: [Errno 2] No such file or directory: '42matters.json'

# %%
# Create the api search url and assign it to a variable. After reviewing the information about the api, i determined 
# that app_primary_genres, id of 6014 is the game category. Combine that with my access token to get the final url.
request_url = 'https://data.42matters.com/api/meta/ios/apps/app_primary_genres.json?id=6014&access_token='
url = request_url + access_token

# %%
# Run the request for the data, it's supposed to be returned in json format.
uh = urllib.request.urlopen(url)

# %%
# Read and decode the data and assign it to a variable
data = uh.read().decode()

# %%
# Load the data in as a dictionary
x = json.loads(data)

# %%
print(data)
# Out:
# {"genres":[{"genreId":6014,"name":"Games"},{"genreId":6000,"name":"Business"},{"genreId":6001,"name":"Weather"},{"genreId":6002,"name":"Utilities"},{"genreId":6003,"name":"Travel"},{"genreId":6004,"name":"Sports"},{"genreId":6005,"name":"Social Networking"},{"genreId":6006,"name":"Reference"},{"genreId":6007,"name":"Productivity"},{"genreId":6008,"name":"Photo & Video"},{"genreId":6009,"name":"News"},{"genreId":6010,"name":"Navigation"},{"genreId":6011,"name":"Music"},{"genreId":6012,"name":"Lifestyle"},{"genreId":6013,"name":"Health & Fitness"},{"genreId":6015,"name":"Finance"},{"genreId":6016,"name":"Entertainment"},{"genreId":6017,"name":"Education"},{"genreId":6018,"name":"Book"},{"genreId":6020,"name":"Medical"},{"genreId":6021,"name":"Magazines & Newspapers"},{"genreId":6022,"name":"Catalogs"},{"genreId":6023,"name":"Food & Drink"},{"genreId":6024,"name":"Shopping"},{"genreId":6025,"name":"Stickers"},{"genreId":6026,"name":"Developer Tools"},{"genreId":6027,"name":"Graphics & Design"}]}

# %%
# Okay...so that's not the data I was looking for. I'm trying to pull down all apps with the genre of 6014, so i'll
# try something different.
request_url = 'https://data.42matters.com/api/v2.0/ios/apps/query.json?primaryGenreId=6014&access_token='
url = request_url + access_token

# %%
uh = urllib.request.urlopen(url)
data = uh.read().decode()
x = json.loads(data)
print(data)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-24-e6db08420257> in <module>
# ----> 1 uh = urllib.request.urlopen(url)
#       2 data = uh.read().decode()
#       3 x = json.loads(data)
#       4 print(data)
#
# ~\anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~\anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# ~\anaconda3\lib\urllib\request.py in http_response(self, request, response)
#     638         # request was successfully received, understood, and accepted.
#     639         if not (200 <= code < 300):
# --> 640             response = self.parent.error(
#     641                 'http', request, response, code, msg, hdrs)
#     642
#
# ~\anaconda3\lib\urllib\request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# ~\anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
#     500         for handler in handlers:
#     501             func = getattr(handler, meth_name)
# --> 502             result = func(*args)
#     503             if result is not None:
#     504                 return result
#
# ~\anaconda3\lib\urllib\request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 400: Bad Request

# %%
# Okay, it was worth a shot. The website has a more advanced search option, but the format is not working in Jupyter.
url = "https://data.42matters.com/api/v2.0/ios/apps/query.json?access_token=" + access_token + -d '{
    "query": {
        "query_params": {
            "primaryGenreId": [
                "6014"
            ]
        }
    }
}'
# Out:
#   File "<ipython-input-38-e5e28178a4f7>", line 2
#     url = "https://data.42matters.com/api/v2.0/ios/apps/query.json?access_token=" + access_token + -d '{
#                                                                                                         ^
# SyntaxError: EOL while scanning string literal

# %%
# After watching a youTube video, I'm going to try to use urllib to parse and encode the query
main_api = "https://data.42matters.com/api/v2.0/ios/apps/query.json?"
main_2nd = "access_token="
full_url = main_api + urllib.parse.urlencode({"query": {"query_params": {"primaryGenreId": ["6014"]}}}) + main_2nd + access_token

# %%
# Request the data
json_data = requests.get(full_url).json()

# %%
# View the output
print(json_data)
# Out:
# {'statusCode': 400, 'message': 'Please provide a valid access token', 'request': 'http://data.42matters.com/api/v2.0/ios/apps/query.json?query=%7B%27query_params%27%3A+%7B%27primaryGenreId%27%3A+%5B%276014%27%5D%7D%7Daccess_token=4ed5787fac18013c1b86a94a38b6bafb95ddd7f7'}

# %%
# And there it is...my access token is returning as not valid. I verified it was correct, but the website I'm using 
# has different levels of plans and I just signed up for the 14 day free trial to do this project. I think that my 
# free trial doesn't allow me to conduct this advanced search.

# %% [markdown]
# ***Unable to use the API to retrieve the iOS app data, I decided to continue with a different API site***

# %%
# Import necessary libraries
import urllib.request, urllib.parse, urllib.error
import requests
import json
import pandas as pd

# %%
# I choose cheapshark api, which should return a list of games deals and the games associated metadata
url = "https://www.cheapshark.com/api/1.0/deals?upperPrice=50"

# %%
# Put request into api and return data, decode it, and then use json loads to read the string in as a list of dictionaries.
uh = urllib.request.urlopen(url)
data = uh.read().decode()
x = json.loads(data)
print(data)
# Out:
# [{"internalName":"NARUTOTOBORUTOSHINOBISTRIKERDELUXEEDITION","title":"Naruto to Boruto Shinobi Striker - Deluxe Edition","metacriticLink":null,"dealID":"RCszdBxkwgB6%2F7YS3Cvf6OMqiDBS3KLT1Z%2BHyfMGSK8%3D","storeID":"30","gameID":"189692","salePrice":"11.99","normalPrice":"79.98","isOnSale":"1","savings":"85.008752","metacriticScore":"0","steamRatingText":null,"steamRatingPercent":"0","steamRatingCount":"0","steamAppID":null,"releaseDate":0,"lastChange":1605520670,"dealRating":"10.0","thumb":"https:\/\/images.greenmangaming.com\/bea8652cdc044930bc603ea6e843b0bb\/1d7901df5b8843c2965b9b97f3361afc.jpg"},{"internalName":"NINOKUNIIIREVENANTKINGDOMTHEPRINCESEDITION","title":"Ni no Kuni II: Revenant Kingdom - The Prince's Edition","metacriticLink":null,"dealID":"%2B1tswYlB4zRWeV8rgSP6GuU830CA2Euec3Y%2BL121dnU%3D","storeID":"30","gameID":"171780","salePrice":"11.99","normalPrice":"79.98","isOnSale":"1","savings":"85.008752","metacriticScore":"0","steamRatingText":null,"steamRatingPercent":"0","steamRatingCount":"0","steamAppID":null,"releaseDate":0,"lastChange":1605536168,"dealRating":"10.0","thumb":"https:\/\/images.greenmangaming.com\/42b323a5cc0f4aa1899364b0e501ebd0\/e5791e804a894158a81e6e8f772ad0e3.jpg"},{"internalName":"PROJECTCARS2DELUXEEDITION","title":"Project CARS 2 - Deluxe Edition","metacriticLink":null,"dealID":"RKQ4vUlz9KoXZILayNkOBnaBxP1BWqReQlrvI1sqdmE%3D","storeID":"30","gameID":"170776","salePrice":"13.49","normalPrice":"89.99","isOnSale":"1","savings":"85.009445","metacriticScore":"0","steamRatingText":null,"steamRatingPercent":"0","steamRatingCount":"0","steamAppID":null,"releaseDate":0,"lastChange":1605520504,"dealRating":"10.0","thumb":"https:\/\/images.greenmangaming.com\/db350afbcffc40cba712e1886196063a\/513986ddb169414fa20aefabfd4d5657.jpg"},{"internalName":"DRAGONBALLFIGHTERZFIGHTERZEDITION","title":"Dragon Ball Fighter Z  FighterZ Edition","metacriticLink":null,"dealID":"%2BRv0gRP7cWHEhyD3G%2BhetsTy4zEpSgtDFe99BG8cw7U%3D","storeID":"30","gameID":"174472","salePrice":"14.24","normalPrice":"94.98","isOnSale":"1","savings":"85.007370","metacriticScore":"0","steamRatingText":null,"steamRatingPercent":"0","steamRatingCount":"0","steamAppID":null,"releaseDate":0,"lastChange":1605520684,"dealRating":"10.0","thumb":"https:\/\/images.greenmangaming.com\/1aaa5e509b074fd7a2a0df69f2983401\/9920f9cf5bc84897995fdc70f9f79ed1.jpg"},{"internalName":"DRAGONBALLFIGHTERZULTIMATEEDITION","title":"Dragon Ball Fighter Z  Ultimate Edition","metacriticLink":null,"dealID":"HOs%2BNeYdewoXfuxkwHA5z9gNUqQIejbxK%2BwrFiSmEL0%3D","storeID":"30","gameID":"174473","salePrice":"16.49","normalPrice":"109.97","isOnSale":"1","savings":"85.005001","metacriticScore":"0","steamRatingText":null,"steamRatingPercent":"0","steamRatingCount":"0","steamAppID":null,"releaseDate":0,"lastChange":1605520684,"dealRating":"10.0","thumb":"https:\/\/images.greenmangaming.com\/33077208537a4624aa4550a636a58517\/3085b7d47d2f4eba942b258ed90503fa.jpg"},{"internalName":"NARUTOTOBORUTOSHINOBISTRIKERDELUXEEDITION","title":"Naruto to Boruto Shinobi Striker - Deluxe Edition","metacriticLink":null,"dealID":"n7UU3i9aHC2S5GiQyf5WCjRqf616%2BdA1d2nVpkwLihY%3D","storeID":"11","gameID":"189692","salePrice":"12.79","normalPrice":"79.98","isOnSale":"1","savings":"84.008502","metacriticScore":"0","steamRatingText":null,"steamRatingPercent":"0","steamRatingCount":"0","steamAppID":null,"releaseDate":0,"lastChange":1605229807,"dealRating":"10.0","thumb":"https:\/\/images.greenmangaming.com\/bea8652cdc044930bc603ea6e843b0bb\/1d7901df5b8843c2965b9b97f3361afc.jpg"},{"internalName":"ONEPIECEBURNINGBLOODGOLDEDITION","title":"ONE PIECE BURNING BLOOD GOLD EDITION","metacriticLink":"\/game\/pc\/one-piece-burning-blood---gold-edition","dealID":"jvYdAhJexcrvD7IFEJiPzaTrrawLfp80WYsraKhijUI%3D","storeID":"21","gameID":"157072","salePrice":"11.99","normalPrice":"74.98","isOnSale":"1","savings":"84.009069","metacriticScore":"0","steamRatingText":null,"steamRatingPercent":"0","steamRatingCount":"0","s ...

# %%
# I want to take a look at what the data looks like, so I'm going to use a for loop to print out one games info.
y = x[0]
for k,v in y.items():
    print("{}: {}".format(k,v))
# Out:
# internalName: NARUTOTOBORUTOSHINOBISTRIKERDELUXEEDITION
# title: Naruto to Boruto Shinobi Striker - Deluxe Edition
# metacriticLink: None
# dealID: RCszdBxkwgB6%2F7YS3Cvf6OMqiDBS3KLT1Z%2BHyfMGSK8%3D
# storeID: 30
# gameID: 189692
# salePrice: 11.99
# normalPrice: 79.98
# isOnSale: 1
# savings: 85.008752
# metacriticScore: 0
# steamRatingText: None
# steamRatingPercent: 0
# steamRatingCount: 0
# steamAppID: None
# releaseDate: 0
# lastChange: 1605520670
# dealRating: 10.0
# thumb: https://images.greenmangaming.com/bea8652cdc044930bc603ea6e843b0bb/1d7901df5b8843c2965b9b97f3361afc.jpg

# %%
# OK. It's looking good. Not really what I wanted, but i'll work with it. Time to turn it into a pandas dataframe.
df = pd.DataFrame(x)
df
# Out:
#                                          internalName  \
# 0           NARUTOTOBORUTOSHINOBISTRIKERDELUXEEDITION
# 1          NINOKUNIIIREVENANTKINGDOMTHEPRINCESEDITION
# 2                           PROJECTCARS2DELUXEEDITION
# 3                   DRAGONBALLFIGHTERZFIGHTERZEDITION
# 4                   DRAGONBALLFIGHTERZULTIMATEEDITION
# 5           NARUTOTOBORUTOSHINOBISTRIKERDELUXEEDITION
# 6                     ONEPIECEBURNINGBLOODGOLDEDITION
# 7          NINOKUNIIIREVENANTKINGDOMTHEPRINCESEDITION
# 8                           PROJECTCARS2DELUXEEDITION
# 9                   DRAGONBALLFIGHTERZFIGHTERZEDITION
# 10                             TEKKEN7ULTIMATEEDITION
# 11                      HOMEWORLDREMASTEREDCOLLECTION
# 12                  DRAGONBALLFIGHTERZULTIMATEEDITION
# 13                          DARKSOULSIIIDELUXEEDITION
# 14         THEWITCHER2ASSASSINSOFKINGSENHANCEDEDITION
# 15                         SOULCALIBURVIDELUXEEDITION
# 16                             JUMPFORCEDELUXEEDITION
# 17                               THESURVIOSCOLLECTION
# 18                                  ZOMBIENIGHTTERROR
# 19              THEWITCHERENHANCEDEDITIONDIRECTORSCUT
# 20                                     FELIXTHEREAPER
# 21                  DEUSEXHUMANREVOLUTIONDIRECTORSCUT
# 22                       ROBINHOODTHELEGENDOFSHERWOOD
# 23                                             CANDLE
# 24                           JUMPFORCEULTIMATEEDITION
# 25                     WEHAPPYFEWDIGITALDELUXEEDITION
# 26                                 FARCRY5GOLDEDITION
# 27                           RETURNTOMYSTERIOUSISLAND
# 28                                       BADDREAMCOMA
# 29                                     METRO2033REDUX
# 30                                            MEMORIA
# 31         FARCRY5ANDFARCRYNEWDAWNDELUXEEDITIONBUNDLE
# 32                                 THIEFDEADLYSHADOWS
# 33                                         JUSTCAUSE2
# 34                                 THIEFIITHEMETALAGE
# 35                           HOMEWORLDDESERTSOFKHARAK
# 36                                            CHARIOT
# 37                     SHADOWTACTICSBLADESOFTHESHOGUN
# 38                                          STILLLIFE
# 39                                            RAWDATA
# 40                                       DUNGEONSIEGE
# 41                                    WEARETHEDWARVES
# 42                              TOMBRAIDERANNIVERSARY
# 43                                            DEPONIA
# 44                        EDNAANDHARVEYHARVEYSNEWEYES
# 45                          THEDARKEYECHAINSOFSATINAV
# 46                                THENIGHTOFTHERABBIT
# 47                     WEHAPPYFEWDIGITALDELUXEEDITION
# 48                                       BLACKGUARDS2
# 49                                   YESTERDAYORIGINS
# 50                      BATTLETECHMERCENARYCOLLECTION
# 51                                         ANNASQUEST
# 52                                           RAGEJUMP
# 53                                 DRAGONBALLFIGHTERZ
# 54  FARCRY5GOLDEDITIONANDFARCRYNEWDAWNDELUXEEDITIO...
# 55                          THELASTTINKERCITYOFCOLORS
# 56                              ANEWBEGINNINGFINALCUT
# 57                                     HARDRESETREDUX
# 58                                           HARDWEST
# 59                      CITIESINMOTION1AND2COLLECTION
#
#                                                 title  \
# 0   Naruto to Boruto Shinobi Striker - Deluxe Edition
# 1   Ni no Kuni II: Revenant Kingdom - The Prince's...
# 2                     Project CARS 2 - Deluxe Edition
# 3             Dragon Ball Fighter Z  FighterZ Edition
# 4             Dragon Ball Fighter Z  Ultimate Edition
# 5   Naruto to Boruto Shinobi Striker - Deluxe Edition
# 6                ONE PIECE BURNING BLOOD GOLD EDITION
# 7   Ni no Kuni II: Revenant Kingdom - The Prince's...
# 8                     Project CARS 2 - Deluxe Edition
# 9             Dragon Ball Fighter Z  FighterZ Edition
# 10                          TEKKEN 7 Ultimate Edition
# 11                    Homeworld Remastered Collection
# 12            Dragon Ball Fighter Z  Ultimate Edition
# 13                      Dark Souls III Deluxe Edition
# 14  The Witcher 2: Assassins of Kings Enhanced Edi...
# 15                      SOULCALIBUR VI Deluxe Edition
# 16                        JUMP FORCE - Deluxe Edition
# 17                             The Survios Collection
# 18                                Zombie Night Terror
# 19       The Witcher: Enhanced Edition Director's Cut
# 20                                   Felix The Reaper
# 21         Deus Ex: Human Revolution - Director's Cut
# 22                 Robin Hood: The Legend of Sherwood
# 23                                             Candle
# 24                      JUMP FORCE - Ultimate Edition
# 25                We Happy Few Digital Deluxe Edition
# 26                             Far Cry 5 Gold Edition
# 27                        Return To Mysterious Island
# 28                                    Bad Dream: Coma
# 29                                   Metro 2033 Redux
# 30                                            Memoria
# 31  Far Cry 5 and Far Cry New Dawn Deluxe Edition ...
# 32                              Thief: Deadly Shadows
# 33                                       Just Cause 2
# 34                            Thief II: The Metal Age
# 35                       Homeworld: Deserts of Kharak
# 36                                            Chariot
# 37               Shadow Tactics: Blades of the Shogun
# 38                                         Still Life
# 39                                           Raw Data
# 40                                      Dungeon Siege
# 41                                 We Are The Dwarves
# 42                           Tomb Raider: Anniversary
# 43                                            Deponia
# 44                 Edna and Harvey: Harvey's New Eyes
# 45                    The Dark Eye: Chains of Satinav
# 46                            The Night of the Rabbit
# 47                We Happy Few Digital Deluxe Edition
# 48                                      Blackguards 2
# 49                                  Yesterday Origins
# 50                    BATTLETECH Mercenary Collection
# 51                                       Anna's Quest
# 52                                          Rage Jump
# 53                               DRAGON BALL FighterZ
# 54  Far Cry 5 Gold Edition and Far Cry New Dawn De...
# 55                    The Last Tinker: City of Colors
# 56                        A New Beginning - Final Cut
# 57                                   Hard Reset Redux
# 58                                          Hard West
# 59                Cities in Motion 1 and 2 Collection
#
#                                        metacriticLink  \
# 0                                                None
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6     /game/pc/one-piece-burning-blood---gold-edition
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                               None
# 11           /game/pc/homeworld-remastered-collection
# 12                                               None
# 13                                               None
# 14          /game/pc/the-witcher-2-assassins-of-kings
# 15                                               None
# 16                                               None
# 17                                               None
# 18                       /game/pc/zombie-night-terror
# 19              /game/pc/the-witcher-enhanced-edition
# 20                          /game/pc/felix-the-reaper
# 21  /game/pc/deus-ex-human-revolution---directors-cut
# 22         /game/pc/robin-hood-the-legend-of-sherwood
# 23                                    /game/pc/candle
# 24                                               None
# 25                                               None
# 26                                               None
# 27               /game/pc/return-to-mysterious-island
# 28                            /game/pc/bad-dream-coma
# 29                          /game/pc/metro-2033-redux
# 30                                   /game/pc/memoria
# 31                                               None
# 32                      /game/pc/thief-deadly-shadows
# 33                              /game/pc/just-cause-2
# 34                    /game/pc/thief-ii-the-metal-age
# 35               /game/pc/homeworld-deserts-of-kharak
# 36                                   /game/pc/chariot
# 37       /game/pc/shadow-tactics-blades-of-the-shogun
# 38                                /game/pc/still-life
# 39                                  /game/pc/raw-data
# 40                             /game/pc/dungeon-siege
# 41                        /game/pc/we-are-the-dwarves
# 42                   /game/pc/tomb-raider-anniversary
# 43                                   /game/pc/deponia
# 44              /game/pc/edna-harvey-harveys-new-eyes
# 45            /game/pc/the-dark-eye-chains-of-satinav
# 46                   /game/pc/the-night-of-the-rabbit
# 47                                               None
# 48                             /game/pc/blackguards-2
# 49                         /game/pc/yesterday-origins
# 50                                               None
# 51                               /game/pc/annas-quest
# 52                                 /game/pc/rage-jump
# 53                      /game/pc/dragon-ball-fighterz
# 54                                               None
# 55            /game/pc/the-last-tinker-city-of-colors
# 56                 /game/pc/a-new-beginning-final-cut
# 57                          /game/pc/hard-reset-redux
# 58                                 /game/pc/hard-west
# 59                                               None
#
#                                                dealID storeID  gameID  \
# 0   RCszdBxkwgB6%2F7YS3Cvf6OMqiDBS3KLT1Z%2BHyfMGSK...      30  189692
# 1   %2B1tswYlB4zRWeV8rgSP6GuU830CA2Euec3Y%2BL121dn...      30  171780
# 2      RKQ4vUlz9KoXZILayNkOBnaBxP1BWqReQlrvI1sqdmE%3D      30  170776
# 3   %2BRv0gRP7cWHEhyD3G%2BhetsTy4zEpSgtDFe99BG8cw7...      30  174472
# 4   HOs%2BNeYdewoXfuxkwHA5z9gNUqQIejbxK%2BwrFiSmEL...      30  174473
# 5    n7UU3i9aHC2S5GiQyf5WCjRqf616%2BdA1d2nVpkwLihY%3D      11  189692
# 6      jvYdAhJexcrvD7IFEJiPzaTrrawLfp80WYsraKhijUI%3D      21  157072
# 7   4WgIa%2B%2FZ92mZjM3AEjmCLu4WIRiygLDiV4CuN7LMBO...      11  171780
# 8    KVL74HNE7GnWkQesIdXd%2BEOf7tpLTeobtBkk7Fj4b3Q%3D      11  170776
# 9      0cB8snrNQRgQ7dFFOent0o0l3sC5EUy4D0uQEazVZtA%3D      11  174472
# 10  Mc%2FVzJ3yKxHjtQ8QAvlfFN0in5xKxMx4irV5Hmw%2FjD...      30  192149
# 11  skE16m6d%2FlvPGahH%2Fpmu1nogLtWGk9yZufNNEzESn5...       7  141243
# 12   ur3Mlk%2BM0lSksHh59YdHcWZZVfp4CSKUzvwPnClujyM%3D      11  174473
# 13  3jAnaYVws%2FGo9oYamg%2FYl%2FxGbm5UMJR6f0%2BOPL...      30  149981
# 14  wbwSwOEEf%2FXwtxjY8CVuiEfXM4NXhJq6i8wy%2FJbS5a...       7    5572
# 15     qjjGcnb0MXJ07JendJ1yWdHo912eRJ89n4ONFC3TaMg%3D      30  191458
# 16   KhZWfVavEM09bNR9BOfxE%2BqH9ztf0LeH8OrInT80hCI%3D      30  195192
# 17   uwvWBNra5DGizCaeMDBRJKs9JDNE8WTw3qcWn%2BTADAg%3D       3  215215
# 18  kfwmtdgaQCWWgiQOf5nL4d5%2BMuEwy%2Bo5avHGyMJVF4...       1  154629
# 19  aZ%2F7TtJLwk3XO9Grnstt0GRZGQamrpM6%2BMdi%2BZIQ...       7     188
# 20     pApcdZ80lQEgMKwvtMZcsDIJGLri9gCFqfWY0CAC9x4%3D       7  206344
# 21  HhzMJAgQYGZ%2B%2BFPpBG%2BRFcuUQZJO3KXvlnyYYGwG...       1  102249
# 22   tZDeQrNXQv08JZ8E9w07s1ihqdQQsfthRpqOFqw%2Fp7E%3D       1     231
# 23     db2UsPUHqIkMPI94f82QBrYP50DUpNVMo7cP3mfgdiE%3D       7  155405
# 24   dl0HSwHMjzQLwRNB4ZU9pxMW8%2FCvqZRsStm0pN6H1x4%3D      30  195191
# 25     DUifWXrfVVDTTwmDRh3XvTGz04fxpN1FDvz6zMQzHxM%3D      23  191733
# 26     NB7S2ajN3NH9lwZapS7yUwF01GRloFR4mknDJGkMbHk%3D      11  169242
# 27  LTDErR6X0bh7Dk%2F1qCJHkC7K9VDfbWM3IWOveX4%2BUu...       1    3394
# 28     FGIQ3MYKHgDyNptlDImabIZSphzrbg1hZletrZJ0pf0%3D       7  177327
# 29  PHhCNxt3lEqSWT%2FtyenATp%2BW76KSYsFJzGMLw96qvI...       3  109746
# 30  gvknsArXVKx%2FVI9cF1lKsxH8xMoh47G%2FUjZ2bSpu%2...       7  101345
# 31  VInMhsJ%2F5VKKxv1MJWk5lvGgKiq9HjcIiewGo%2FPmGc...      11  198630
# 32  EX0oH20b7A1H2YiVjvVx5A0HH%2F4etw3x%2F6YMGVPpKb...       1     396
# 33  z4El8C19yCEHrk1%2ByEedebThQVbblI7H0Z%2BAmxgZiS...       1     180
# 34   TlzUCY9p3Sq1bY%2Br4aGWO5Cs2UxE1lYnuQD05gxNwIM%3D       1   87640
# 35  hoslUy50mV3Ie5UD57l1jdbUIYkH%2B4ZOsU3mS%2Brf9Z...       7  147543
# 36   SJtwMqHmcdHzhryD5NoKvH6Nnk%2BblWEhlew2F42uPHk%3D       1  137348
# 37  evPHVt7ofnWKB48WqFd8YaqH6sGGEZO6%2FaJ5%2F80L1Y...       7  158443
# 38  eP%2B5kpe%2B8NrZItn0kjLXtJnb3SmjgFnVGVZ063AUdU...       1     472
# 39  QjOdVBdWe6aMrIpwlcRciRQkS1%2FodpTrGrdE%2BEUYVh...       3  154911
# 40   Hli8KbDatTjYjj%2BjpnfUuVKjxPwQPmblW1llCXyMMmU%3D       1     192
# 41   hRoi%2BoFY01lHi3w8En3hHZ0nuemTCRZEs7lL1hx9hA8%3D       7  150371
# 42   ryaV37fbWkAIG6ZLy%2FtViuEGOIShgUVV7kpgbYlDqQk%3D       1     456
# 43     dPK8I7bvxp27skMiKlTMGlm1ne0FMXT73a7eMypvkk0%3D       7   88328
# 44  ovvLBIR6Zz9LsuNgNiY1cM%2FV%2FS1jU1zpGFwdWvUf6N...       7   93463
# 45   ybwdr22CGuRBjBU0xCkHO%2FXwFN9KOeHePpSUlF0LG74%3D       7   87946
# 46  pul24yrXUi5699RcrUPv7F%2Fa17pxA3jc18c4bB%2Bp4v...       7   97671
# 47   yb7qds%2FfAll5jWc7rBXmryHIJYdIBPy6IB3iUfhTkvo%3D      28  191733
# 48  OVL5eDN5s1M2hr5vK3E%2FQNX6u%2Fg51KkBldO7Z0ONbH...       7  140070
# 49   oyZTlHlRK0ilD3ULb%2FZkiPiKsD0oC5bNawI4GiuwU0M%3D       1  157512
# 50  qGpNLrhXI%2Bc8wG9bdL%2BfzR%2FrnFdAS%2FnoRReS%2...      30  193595
# 51   kEtV9uJjhMLxsBeg5OxJMLCirymC0TFCKcBCcORVH%2FI%3D       7  144487
# 52  0WtTQZeED1mqD1Nk6Wg53r%2Fp74F%2Fel21Q%2Fz0gzS7...       1  220795
# 53  7bYA9DDvkm8I2oOQHTKYow9e%2B5Q4ePauzXH%2BQ4a3yD...      30  174454
# 54     TmzhiDnhS8hdqYB3uOKYr7x2cbQ0mZZ6XAHh8gXpaPE%3D      11  198638
# 55  lOoogg5zmh6WuOQ4Mb8x0BWqzI9%2BcFz%2FP%2Fza7TCB...       7  108708
# 56   SYqHPUSl9TH9C8HIsUE2KHUFFJFwZh31QDfOj4VQR%2FM%3D       7   94063
# 57  0REspY4RODVxx%2F0GINg%2FOe2TYXaUsWFbQwsWPVa9l5...       7  153146
# 58  V9h%2BdnRzJcyv63kxEKis3ZHl7%2FyUg4WfoRqSsBYU2r...       7  146570
# 59   mjcLUGqpWryeZMaw7yFi4mpZn2I%2Fk2Fvd4G324d1ins%3D      30  109242
#
#    salePrice normalPrice isOnSale    savings metacriticScore  \
# 0      11.99       79.98        1  85.008752               0
# 1      11.99       79.98        1  85.008752               0
# 2      13.49       89.99        1  85.009445               0
# 3      14.24       94.98        1  85.007370               0
# 4      16.49      109.97        1  85.005001               0
# 5      12.79       79.98        1  84.008502               0
# 6      11.99       74.98        1  84.009069               0
# 7      12.79       79.99        1  84.010501               0
# 8      14.39       89.99        1  84.009334               0
# 9      15.19       94.98        1  84.007159               0
# 10     19.49       89.99        1  78.342038               0
# 11      3.49       34.99        1  90.025722              86
# 12     17.59      109.97        1  84.004729               0
# 13     19.99       84.98        1  76.476818               0
# 14      2.99       19.99        1  85.042521              88
# 15     21.49       89.99        1  76.119569               0
# 16     21.49       89.99        1  76.119569               0
# 17     29.32      149.95        1  80.446816               0
# 18      1.29       12.99        1  90.069284              81
# 19      1.49        9.99        1  85.085085              86
# 20      2.99       24.99        1  88.035214              71
# 21      2.99       19.99        1  85.042521              91
# 22      0.79        7.99        1  90.112641              80
# 23      1.49       14.99        1  90.060040              80
# 24     23.99       99.99        1  76.007601               0
# 25     18.82       87.97        1  78.606343               0
# 26     17.99       89.99        1  80.008890               0
# 27      0.79        7.99        1  90.112641              79
# 28      0.89        8.99        1  90.100111              79
# 29      3.00       19.99        1  84.992496              90
# 30      1.99       19.99        1  90.045023              79
# 31     19.99       99.99        1  80.008001               0
# 32      0.98        8.99        1  89.098999              85
# 33      1.49       14.99        1  90.060040              84
# 34      0.97        6.99        1  86.123033              87
# 35      4.99       49.99        1  90.018004              79
# 36      1.49       14.99        1  90.060040              76
# 37      5.99       39.99        1  85.021255              85
# 38      0.79        7.99        1  90.112641              75
# 39      6.80       39.99        1  82.995749              87
# 40      0.97        6.99        1  86.123033              86
# 41      0.74       14.99        1  95.063376              60
# 42      0.98        8.99        1  89.098999              83
# 43      0.99        9.99        1  90.090090              74
# 44      1.99       19.99        1  90.045023              75
# 45      1.99       19.99        1  90.045023              75
# 46      1.99       19.99        1  90.045023              75
# 47     21.09       87.97        1  76.025918               0
# 48      1.49       14.99        1  90.060040              74
# 49      1.49       14.99        1  90.060040              74
# 50     21.59       89.99        1  76.008445               0
# 51      1.99       19.99        1  90.045023              74
# 52      1.69       16.99        1  90.052972               0
# 53      8.99       59.99        1  85.014169              85
# 54     25.99      129.99        1  80.006154               0
# 55      0.99        9.99        1  90.090090              72
# 56      0.99        9.99        1  90.090090              72
# 57      1.99       19.99        1  90.045023              73
# 58      1.99       19.99        1  90.045023              73
# 59     21.24       84.99        1  75.008825               0
#
#             steamRatingText steamRatingPercent steamRatingCount steamAppID  \
# 0                      None                  0                0       None
# 1                      None                  0                0       None
# 2                      None                  0                0       None
# 3                      None                  0                0       None
# 4                      None                  0                0       None
# 5                      None                  0                0       None
# 6                      None                  0                0       None
# 7                      None                  0                0       None
# 8                      None                  0                0       None
# 9                      None                  0                0       None
# 10                     None                  0                0       None
# 11            Very Positive                 88             7290     244160
# 12                     None                  0                0       None
# 13            Very Positive                 93           142105      94174
# 14            Very Positive                 89            51810      20920
# 15                     None                  0                0       None
# 16                     None                  0                0       None
# 17                     None                  0                0       None
# 18            Very Positive                 93             1628     416680
# 19            Very Positive                 88            47909      20900
# 20            Very Positive                 87               88     919410
# 21            Very Positive                 91            15921     238010
# 22                    Mixed                 60              754      46560
# 23            Very Positive                 80              477     420060
# 24                     None                  0                0       None
# 25                     None                  0                0       None
# 26                     None                  0                0       None
# 27          Mostly Positive                 79              208     277110
# 28            Very Positive                 91             1070     538070
# 29            Very Positive                 85            42020     286690
# 30            Very Positive                 90             1484     243200
# 31                     None                  0                0       None
# 32            Very Positive                 82             1538       6980
# 33            Very Positive                 90            33534       8190
# 34            Very Positive                 93             1084     211740
# 35            Very Positive                 81             4414     281610
# 36            Very Positive                 82              173     319450
# 37  Overwhelmingly Positive                 96            16177     418240
# 38            Very Positive                 82              532      46480
# 39            Very Positive                 84             1884     436320
# 40          Mostly Positive                 78             2116      39190
# 41          Mostly Positive                 70              498     395570
# 42            Very Positive                 82             3159       8000
# 43            Very Positive                 88             7262     214340
# 44            Very Positive                 89             1736     219910
# 45            Very Positive                 86             1414     203830
# 46            Very Positive                 90             1861     230820
# 47                     None                  0                0       None
# 48                    Mixed                 63              615     314830
# 49            Very Positive                 82              260     465280
# 50                     None                  0                0       None
# 51            Very Positive                 87              987     327220
# 52                     None                  0                0    1414900
# 53            Very Positive                 88            20173     678950
# 54                     None                  0                0       None
# 55          Mostly Positive                 77              544     260160
# 56          Mostly Positive                 74             1088     105000
# 57            Very Positive                 81             1160     407810
# 58          Mostly Positive                 77             2890     307670
# 59                     None                  0                0       None
#
#     releaseDate  lastChange dealRating  \
# 0             0  1605520670       10.0
# 1             0  1605536168       10.0
# 2             0  1605520504       10.0
# 3             0  1605520684       10.0
# 4             0  1605520684       10.0
# 5             0  1605229807       10.0
# 6    1472688000  1605223018       10.0
# 7             0  1605209422        9.9
# 8             0  1605209466        9.9
# 9             0  1605213743        9.8
# 10            0  1605520512        9.8
# 11   1424822400  1605538398        9.8
# 12            0  1605209462        9.7
# 13            0  1605520750        9.6
# 14   1305590400  1605538379        9.6
# 15            0  1605520632        9.5
# 16            0  1605520724        9.5
# 17            0  1605490033        9.5
# 18   1468972800  1605553708        9.5
# 19   1221523200  1605538390        9.5
# 20   1571270400  1605538683        9.5
# 21   1382400000  1605292672        9.5
# 22   1037232000  1605554580        9.5
# 23   1478822400  1605538593        9.4
# 24            0  1605520725        9.4
# 25            0  1605289960        9.4
# 26            0  1605209561        9.4
# 27   1099353600  1605553984        9.4
# 28   1489017600  1605538685        9.4
# 29   1408924800  1605283407        9.4
# 30   1377734400  1605538553        9.3
# 31            0  1605209452        9.3
# 32   1085443200  1605293140        9.3
# 33   1269302400  1605292812        9.3
# 34    953769600  1605293128        9.2
# 35   1453248000  1605538422        9.2
# 36   1415750400  1605554391        9.2
# 37   1480982400  1605538650        9.2
# 38   1115164800  1605554075        9.2
# 39   1507161600  1605487150        9.2
# 40   1017532800  1605293225        9.2
# 41   1456358400  1605625371        9.2
# 42   1181001600  1605293081        9.1
# 43   1344211200  1605538483        9.1
# 44   1350345600  1605538558        9.1
# 45   1340323200  1605538513        9.1
# 46   1369699200  1605538453        9.1
# 47            0  1605283495        9.1
# 48   1421712000  1605538566        9.1
# 49   1478736000  1605554313        9.1
# 50            0  1605265456        9.1
# 51   1435795200  1605538605        9.1
# 52   1600819200  1605122435        9.1
# 53   1516924800  1605520684        9.1
# 54            0  1605209446        9.1
# 55   1399852800  1605538597        9.0
# 56   1355184000  1605538486        9.0
# 57   1464912000  1605538460        9.0
# 58   1447804800  1605538509        9.0
# 59            0  1605270009        9.0
#
#                                                 thumb
# 0   https://images.greenmangaming.com/bea8652cdc04...
# 1   https://images.greenmangaming.com/42b323a5cc0f...
# 2   https://images.greenmangaming.com/db350afbcffc...
# 3   https://images.greenmangaming.com/1aaa5e509b07...
# 4   https://images.greenmangaming.com/33077208537a...
# 5   https://images.greenmangaming.com/bea8652cdc04...
# 6   https://images.greenmangaming.com/de83e6c99ef1...
# 7   https://images.greenmangaming.com/42b323a5cc0f...
# 8   https://images.greenmangaming.com/db350afbcffc...
# 9   https://images.greenmangaming.com/1aaa5e509b07...
# 10  https://images.greenmangaming.com/63b80db5e046...
# 11  https://cdn.cloudflare.steamstatic.com/steam/a...
# 12  https://images.greenmangaming.com/33077208537a...
# 13  https://cdn.cloudflare.steamstatic.com/steam/s...
# 14  https://cdn.cloudflare.steamstatic.com/steam/a...
# 15  https://images.greenmangaming.com/152edc10ed98...
# 16  https://images.greenmangaming.com/c8466c85b53a...
# 17  https://images.greenmangaming.com/80d91f9b6230...
# 18  https://cdn.cloudflare.steamstatic.com/steam/a...
# 19  https://cdn.cloudflare.steamstatic.com/steam/a...
# 20  https://cdn.cloudflare.steamstatic.com/steam/a...
# 21  https://cdn.cloudflare.steamstatic.com/steam/a...
# 22  https://cdn.cloudflare.steamstatic.com/steam/a...
# 23  https://cdn.cloudflare.steamstatic.com/steam/a...
# 24  https://images.greenmangaming.com/97bb8a588c7f...
# 25  https://hb.imgix.net/e59a3c20aa99d50e61bd04255...
# 26  https://gamersgatep.imgix.net/f/9/6/3b855d0007...
# 27  https://cdn.cloudflare.steamstatic.com/steam/a...
# 28  https://cdn.cloudflare.steamstatic.com/steam/a...
# 29  https://cdn.cloudflare.steamstatic.com/steam/a...
# 30  https://cdn.cloudflare.steamstatic.com/steam/a...
# 31  https://hb.imgix.net/85970297dbcd85c44bd2112f2...
# 32  https://cdn.cloudflare.steamstatic.com/steam/a...
# 33  https://cdn.cloudflare.steamstatic.com/steam/a...
# 34  https://cdn.cloudflare.steamstatic.com/steam/a...
# 35  https://cdn.cloudflare.steamstatic.com/steam/a...
# 36  https://cdn.cloudflare.steamstatic.com/steam/a...
# 37  https://cdn.cloudflare.steamstatic.com/steam/a...
# 38  https://cdn.cloudflare.steamstatic.com/steam/a...
# 39  https://cdn.cloudflare.steamstatic.com/steam/a...
# 40  https://cdn.cloudflare.steamstatic.com/steam/a...
# 41  https://cdn.cloudflare.steamstatic.com/steam/a...
# 42  https://cdn.cloudflare.steamstatic.com/steam/a...
# 43  https://cdn.cloudflare.steamstatic.com/steam/a...
# 44  https://cdn.cloudflare.steamstatic.com/steam/a...
# 45  https://cdn.cloudflare.steamstatic.com/steam/a...
# 46  https://cdn.cloudflare.steamstatic.com/steam/a...
# 47  https://hb.imgix.net/e59a3c20aa99d50e61bd04255...
# 48  https://cdn.cloudflare.steamstatic.com/steam/a...
# 49  https://cdn.cloudflare.steamstatic.com/steam/a...
# 50  https://images.greenmangaming.com/153c905a45cf...
# 51  https://cdn.cloudflare.steamstatic.com/steam/a...
# 52  https://cdn.cloudflare.steamstatic.com/steam/a...
# 53  https://cdn.cloudflare.steamstatic.com/steam/a...
# 54  https://hb.imgix.net/3c28372ff9df9f78c5deb5bb6...
# 55  https://cdn.cloudflare.steamstatic.com/steam/a...
# 56  https://cdn.cloudflare.steamstatic.com/steam/a...
# 57  https://cdn.cloudflare.steamstatic.com/steam/a...
# 58  https://cdn.cloudflare.steamstatic.com/steam/a...
# 59  https://images.greenmangaming.com/9f8a62e5174a...

# %%
# Drop the unnecessary columns
games = df.drop(columns=['internalName', 'metacriticLink', 'dealID', 'storeID', 'lastChange', 'thumb', 'steamAppID',
                        'releaseDate', 'isOnSale'])
games.head()
# Out:
#                                                title  gameID salePrice  \
# 0  Naruto to Boruto Shinobi Striker - Deluxe Edition  189692     11.99
# 1  Ni no Kuni II: Revenant Kingdom - The Prince's...  171780     11.99
# 2                    Project CARS 2 - Deluxe Edition  170776     13.49
# 3            Dragon Ball Fighter Z  FighterZ Edition  174472     14.24
# 4            Dragon Ball Fighter Z  Ultimate Edition  174473     16.49
#
#   normalPrice    savings metacriticScore steamRatingText steamRatingPercent  \
# 0       79.98  85.008752               0            None                  0
# 1       79.98  85.008752               0            None                  0
# 2       89.99  85.009445               0            None                  0
# 3       94.98  85.007370               0            None                  0
# 4      109.97  85.005001               0            None                  0
#
#   steamRatingCount dealRating
# 0                0       10.0
# 1                0       10.0
# 2                0       10.0
# 3                0       10.0
# 4                0       10.0

# %%
# Check for duplicates
print(any(games.duplicated()))
# Out:
# False

# %%
# Find columns with NaN values
for col in games.columns:
    miss = games[col].isnull().sum()
    if miss>0:
        print("{} has {} missing values(s)".format(col, miss))
# Out:
# steamRatingText has 24 missing values(s)

# %%
# The steamRatingText column is not a critical variable in my dataset, so I'm choosing to leave it in even though it has 
# a number of missing values.

# Change all string values in the dataframe to lowercase
games_lower = games.apply(lambda x: x.astype(str).str.lower())
games_lower.head()
# Out:
#                                                title  gameID salePrice  \
# 0  naruto to boruto shinobi striker - deluxe edition  189692     11.99
# 1  ni no kuni ii: revenant kingdom - the prince's...  171780     11.99
# 2                    project cars 2 - deluxe edition  170776     13.49
# 3            dragon ball fighter z  fighterz edition  174472     14.24
# 4            dragon ball fighter z  ultimate edition  174473     16.49
#
#   normalPrice    savings metacriticScore steamRatingText steamRatingPercent  \
# 0       79.98  85.008752               0            none                  0
# 1       79.98  85.008752               0            none                  0
# 2       89.99  85.009445               0            none                  0
# 3       94.98  85.007370               0            none                  0
# 4      109.97  85.005001               0            none                  0
#
#   steamRatingCount dealRating
# 0                0       10.0
# 1                0       10.0
# 2                0       10.0
# 3                0       10.0
# 4                0       10.0

# %%
# I want to round the savings column to an integer because it is a percent value
games_lower['savings'].round(0).astype(int)
games_lower.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'str' object has no attribute 'rint'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-948ab992ac2c> in <module>
#       1 # I want to round the savings column to an integer because it is a percent value
# ----> 2 games_lower['savings'].round(0).astype(int)
#       3 games_lower.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in round(self, decimals, *args, **kwargs)
#    2143         """
#    2144         nv.validate_round(args, kwargs)
# -> 2145         result = com.values_from_object(self).round(decimals)
#    2146         result = self._constructor(result, index=self.index).__finalize__(self)
#    2147
#
# TypeError: loop of ufunc does not support argument 0 of type str which has no callable rint method

# %%
# Guess I need to address the types of my columns
games_lower.dtypes
# Out:
# title                 object
# gameID                object
# salePrice             object
# normalPrice           object
# savings               object
# metacriticScore       object
# steamRatingText       object
# steamRatingPercent    object
# steamRatingCount      object
# dealRating            object
# dtype: object

# %%
# Assign all the number columns to numeric  
games_lower['salePrice'] = pd.to_numeric(games_lower['salePrice'])
games_lower['normalPrice'] = pd.to_numeric(games_lower['normalPrice'])
games_lower['savings'] = pd.to_numeric(games_lower['savings'])
games_lower['metacriticScore'] = pd.to_numeric(games_lower['metacriticScore'])
games_lower['steamRatingPercent'] = pd.to_numeric(games_lower['steamRatingPercent'])
games_lower['steamRatingCount'] = pd.to_numeric(games_lower['steamRatingCount'])
games_lower['dealRating'] = pd.to_numeric(games_lower['dealRating'])
games_lower.dtypes
# Out:
# title                  object
# gameID                 object
# salePrice             float64
# normalPrice           float64
# savings               float64
# metacriticScore         int64
# steamRatingText        object
# steamRatingPercent      int64
# steamRatingCount        int64
# dealRating            float64
# dtype: object

# %%
# Now round out the savings to a whole percentage 
games_lower['savings'] = games_lower['savings'].round(0).astype(int)
games_lower.head()
# Out:
#                                                title  gameID  salePrice  \
# 0  naruto to boruto shinobi striker - deluxe edition  189692      11.99
# 1  ni no kuni ii: revenant kingdom - the prince's...  171780      11.99
# 2                    project cars 2 - deluxe edition  170776      13.49
# 3            dragon ball fighter z  fighterz edition  174472      14.24
# 4            dragon ball fighter z  ultimate edition  174473      16.49
#
#    normalPrice  savings  metacriticScore steamRatingText  steamRatingPercent  \
# 0        79.98       85                0            none                   0
# 1        79.98       85                0            none                   0
# 2        89.99       85                0            none                   0
# 3        94.98       85                0            none                   0
# 4       109.97       85                0            none                   0
#
#    steamRatingCount  dealRating
# 0                 0        10.0
# 1                 0        10.0
# 2                 0        10.0
# 3                 0        10.0
# 4                 0        10.0

# %%
# Change column headers
game_deals = games_lower.rename(columns={"title": "game", "gameID": "cheapshark id", "salePrice": "sale price", 
                                         "normalPrice": "reg price", "savings": "percent savings", 
                                         "metacriticScore": "critic score", "steamRatingText": "rating disposition", 
                                         "steamRatingPercent": "steam rating", "steamRatingCount": "steam num reviews",
                                         "dealRating": "deal rating"})
game_deals.head()
# Out:
#                                                 game cheapshark id  \
# 0  naruto to boruto shinobi striker - deluxe edition        189692
# 1  ni no kuni ii: revenant kingdom - the prince's...        171780
# 2                    project cars 2 - deluxe edition        170776
# 3            dragon ball fighter z  fighterz edition        174472
# 4            dragon ball fighter z  ultimate edition        174473
#
#    sale price  reg price  percent savings  critic score rating disposition  \
# 0       11.99      79.98               85             0               none
# 1       11.99      79.98               85             0               none
# 2       13.49      89.99               85             0               none
# 3       14.24      94.98               85             0               none
# 4       16.49     109.97               85             0               none
#
#    steam rating  steam num reviews  deal rating
# 0             0                  0         10.0
# 1             0                  0         10.0
# 2             0                  0         10.0
# 3             0                  0         10.0
# 4             0                  0         10.0

# %%
game_deals.to_csv('game_deals.csv')
